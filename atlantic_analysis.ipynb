# %%
import seaborn as sns
import pandas as pd
atlantic = pd.read_csv("Datasets/Atlantic.csv")

sns.scatterplot(data=atlantic, x="max_sustained_wind", y="central_pressure")
# Out:
# <AxesSubplot:xlabel='max_sustained_wind', ylabel='central_pressure'>
